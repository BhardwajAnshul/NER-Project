# %% [markdown]
# Dataset Description -
# Datasets with text fragments from astrophysics papers, provided by the NASA Astrophysical Data System with manually tagged astronomical facilities and other entities of interest (e.g., celestial objects).
# Datasets are in JSON Lines format (each line is a json dictionary).
# The datasets are formatted similarly to the CONLL2003 format. Each token is associated with an NER tag. The tags follow the "B-" and "I-" convention from the IOB2 syntax
#
# Each entry consists of a dictionary with the following keys:
#
# "unique_id": a unique identifier for this data sample. Must be included in the predictions.
# "tokens": the list of tokens (strings) that form the text of this sample. Must be included in the predictions.
# "ner_tags": the list of NER tags (in IOB2 format)
# The following keys are not strictly needed by the participants:
#
# "ner_ids": the pre-computed list of ids corresponding ner_tags, as given by the dictionary in ner_tags.json
# "label_studio_id", "section", "bibcode": references for internal NASA/ADS use.
#
# Source - https://huggingface.co/datasets/fgrezes/WIESP2022-NER#dataset-description

# %%
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt

# credits -> https://stackoverflow.com/posts/17303428/revisions
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
df = pd.read_parquet('https://github.com/BhardwajAnshul/NER-Project/blob/main/data/WIESP2022-NER-TRAINING.parquet?raw=true')

# %%
len(df)
# Out:
# 573132

# %%
df
# Out:
#                     bibcode  label_studio_id  ner_ids ner_tags   section  \
# 0       2019MNRAS.486.5558S              487       62        O  fulltext
# 1       2019MNRAS.486.5558S              487       62        O  fulltext
# 2       2019MNRAS.486.5558S              487       62        O  fulltext
# 3       2019MNRAS.486.5558S              487       62        O  fulltext
# 4       2019MNRAS.486.5558S              487       62        O  fulltext
# ...                     ...              ...      ...      ...       ...
# 573127  2016A&A...591A..74D             1746       62        O  fulltext
# 573128  2016A&A...591A..74D             1746       62        O  fulltext
# 573129  2016A&A...591A..74D             1746       62        O  fulltext
# 573130  2016A&A...591A..74D             1746       62        O  fulltext
# 573131  2016A&A...591A..74D             1746       62        O  fulltext
#
#             tokens                          unique_id
# 0           Whilst   fulltext_487_2019MNRAS.486.5558S
# 1                a   fulltext_487_2019MNRAS.486.5558S
# 2       reasonable   fulltext_487_2019MNRAS.486.5558S
# 3         harmonic   fulltext_487_2019MNRAS.486.5558S
# 4              fit   fulltext_487_2019MNRAS.486.5558S
# ...            ...                                ...
# 573127       level  fulltext_1746_2016A&A...591A..74D
# 573128         (RV  fulltext_1746_2016A&A...591A..74D
# 573129   intervals  fulltext_1746_2016A&A...591A..74D
# 573130          48  fulltext_1746_2016A&A...591A..74D
# 573131          km  fulltext_1746_2016A&A...591A..74D
#
# [573132 rows x 7 columns]

# %%
df.groupby('tokens').agg(count=('tokens', 'count')).sort_values('count', ascending=False).reset_index().to_csv('counts.csv')

# %%
print(f"{'Column Name':<20} {'Number of Unique Values'}")
for col in df.columns:
    print(f'{col:<20} {df[col].nunique()}')
# Out:
# Column Name          Number of Unique Values
# bibcode              1723
# label_studio_id      1332
# ner_ids              63
# ner_tags             63
# section              2
# tokens               48991
# unique_id            1753

# %%
# Unique entries in ner_ids
pprint(df.ner_ids.unique())
# Out:
# array([62, 15, 17,  4, 35, 27, 30, 61, 18, 49, 24, 55, 12, 43, 22, 21, 52,
#        11, 42, 13, 44, 53, 16, 47, 10, 41, 29,  5, 36,  1, 32,  8, 39,  2,
#        33, 28, 59, 25, 19, 50,  6, 37, 56, 58, 20,  3, 34,  0, 31, 23, 51,
#         7, 38, 26, 14, 45, 48, 60, 57, 54, 46,  9, 40])

# %%
# Unique entries in ner_tags
pprint(df.ner_tags.unique())
# Out:
# array(['O', 'B-Instrument', 'B-Mission', 'B-Citation', 'I-Citation',
#        'B-Telescope', 'B-Wavelength', 'I-Wavelength', 'B-Model',
#        'I-Model', 'B-Software', 'I-Software', 'B-Formula', 'I-Formula',
#        'B-Person', 'B-Organization', 'I-Organization', 'B-Fellowship',
#        'I-Fellowship', 'B-Grant', 'I-Grant', 'I-Person', 'B-Location',
#        'I-Location', 'B-Event', 'I-Event', 'B-URL', 'B-Collaboration',
#        'I-Collaboration', 'B-CelestialObject', 'I-CelestialObject',
#        'B-Dataset', 'I-Dataset', 'B-CelestialObjectRegion',
#        'I-CelestialObjectRegion', 'B-TextGarbage', 'I-TextGarbage',
#        'B-Survey', 'B-ObservationalTechniques',
#        'I-ObservationalTechniques', 'B-ComputingFacility',
#        'I-ComputingFacility', 'I-Survey', 'I-Telescope', 'B-Observatory',
#        'B-CelestialRegion', 'I-CelestialRegion', 'B-Archive', 'I-Archive',
#        'B-Proposal', 'I-Observatory', 'B-Database', 'I-Database', 'B-Tag',
#        'B-Identifier', 'I-Identifier', 'I-Mission', 'I-URL', 'I-Tag',
#        'I-Proposal', 'I-Instrument', 'B-EntityOfFutureInterest',
#        'I-EntityOfFutureInterest'], dtype=object)

# %%
ner_count_df = df['ner_tags'].value_counts().reset_index()
ner_count_df
# Out:
#                        index  ner_tags
# 0                          O    472307
# 1                 I-Citation     18402
# 2             I-Organization     14211
# 3                  I-Formula      8433
# 4             B-Organization      7448
# ..                       ...       ...
# 58                   B-Event        45
# 59              I-Identifier        31
# 60                 I-Mission        27
# 61  I-EntityOfFutureInterest        16
# 62                     I-URL        12
#
# [63 rows x 2 columns]

# %%
# Explore the tags

plt.figure(figsize=(100,40))
plt.hist(df.ner_tags, log=True)
plt.show()

# %%
pprint(list(ner_count_df.ner_tags))
# Out:
# [472307,
#  18402,
#  14211,
#  8433,
#  7448,
#  6360,
#  4080,
#  3916,
#  3478,
#  3384,
#  2940,
#  2206,
#  2088,
#  1800,
#  1691,
#  1583,
#  1573,
#  1404,
#  1244,
#  1035,
#  1017,
#  1015,
#  885,
#  873,
#  809,
#  714,
#  607,
#  598,
#  573,
#  472,
#  467,
#  466,
#  411,
#  399,
#  368,
#  328,
#  306,
#  294,
#  265,
#  259,
#  256,
#  240,
#  223,
#  192,
#  176,
#  158,
#  140,
#  124,
#  112,
#  110,
#  100,
#  100,
#  74,
#  66,
#  61,
#  54,
#  54,
#  52,
#  45,
#  31,
#  27,
#  16,
#  12]

# %%
# Unique entries in section
pprint(df.section.unique())
# Out:
# array(['fulltext', 'acknowledgments'], dtype=object)

# %%
len(df.groupby(['ner_tags', 'section']))
# Out:
# 115

# %%
set(df.query("section=='fulltext'").ner_tags.unique()) - set(df.query("section!='fulltext'").ner_tags.unique())
# Out:
# {'B-CelestialObjectRegion',
#  'B-EntityOfFutureInterest',
#  'B-Formula',
#  'B-Tag',
#  'I-CelestialObjectRegion',
#  'I-EntityOfFutureInterest',
#  'I-Formula',
#  'I-ObservationalTechniques',
#  'I-Tag'}

# %%
set(df.query("section!='fulltext'").ner_tags.unique()) - set(df.query("section=='fulltext'").ner_tags.unique())
# Out:
# {'B-Fellowship', 'I-Fellowship'}

# %%
df.groupby('unique_id').agg(word_count = ('unique_id', 'count')).sort_values('word_count')
# Out:
#                                           word_count
# unique_id
# acknowledgments_1412_2017A&A...608A..57V           7
# acknowledgments_1102_2015MNRAS.446.1347M           8
# acknowledgments_1225_2018MNRAS.478L..95K          11
# acknowledgments_1025_2016MNRAS.456.1955D          12
# acknowledgments_1039_2016MNRAS.457.4330Y          13
# ...                                              ...
# acknowledgments_717_2016ApJ...826..144S          660
# acknowledgments_96_2018ApJ...859..101S           666
# acknowledgments_611_2018A&A...616A..69B          677
# acknowledgments_556_2018ApJ...865...15S          687
# acknowledgments_453_2019ApJ...882...62N          795
#
# [1753 rows x 1 columns]

# %%
df.groupby('unique_id').agg(word_count = ('unique_id', 'count')).sort_values('word_count').head(20)
# Out:
#                                           word_count
# unique_id
# acknowledgments_1412_2017A&A...608A..57V           7
# acknowledgments_1102_2015MNRAS.446.1347M           8
# acknowledgments_1225_2018MNRAS.478L..95K          11
# acknowledgments_1025_2016MNRAS.456.1955D          12
# acknowledgments_1039_2016MNRAS.457.4330Y          13
# acknowledgments_1423_2019ApJ...883...69I          13
# acknowledgments_1422_2019ApJ...887...14A          13
# acknowledgments_1489_2016ApJ...833...55L          15
# acknowledgments_1424_2019ApJ...886..121B          15
# acknowledgments_1009_2016MNRAS.462.2138F          15
# acknowledgments_1313_2019A&A...622L...5V          16
# acknowledgments_1091_2018MNRAS.474.3700K          17
# acknowledgments_1206_2015MNRAS.450L..61H          18
# acknowledgments_1023_2015MNRAS.454..344O          18
# acknowledgments_2_2016A&A...589A..13A             19
# acknowledgments_1018_2018MNRAS.478..342B          19
# acknowledgments_988_2016MNRAS.461.3948P           19
# acknowledgments_492_2015ApJ...802...16Y           19
# acknowledgments_1069_2020MNRAS.491.4960L          20
# acknowledgments_1554_2016ApJ...831...57E          20

# %%
temp = df.groupby('unique_id').agg(word_count = ('unique_id', 'count')).sort_values('word_count')

# %%
temp
# Out:
#                                           word_count
# unique_id
# acknowledgments_1412_2017A&A...608A..57V           7
# acknowledgments_1102_2015MNRAS.446.1347M           8
# acknowledgments_1225_2018MNRAS.478L..95K          11
# acknowledgments_1025_2016MNRAS.456.1955D          12
# acknowledgments_1039_2016MNRAS.457.4330Y          13
# ...                                              ...
# acknowledgments_717_2016ApJ...826..144S          660
# acknowledgments_96_2018ApJ...859..101S           666
# acknowledgments_611_2018A&A...616A..69B          677
# acknowledgments_556_2018ApJ...865...15S          687
# acknowledgments_453_2019ApJ...882...62N          795
#
# [1753 rows x 1 columns]

# %%
temp.describe()
# Out:
#         word_count
# count  1753.000000
# mean    326.943525
# std     209.222148
# min       7.000000
# 25%      98.000000
# 50%     470.000000
# 75%     518.000000
# max     795.000000

# %%
df
# Out:
#                     bibcode  label_studio_id  ner_ids ner_tags   section  \
# 0       2019MNRAS.486.5558S              487       62        O  fulltext
# 1       2019MNRAS.486.5558S              487       62        O  fulltext
# 2       2019MNRAS.486.5558S              487       62        O  fulltext
# 3       2019MNRAS.486.5558S              487       62        O  fulltext
# 4       2019MNRAS.486.5558S              487       62        O  fulltext
# ...                     ...              ...      ...      ...       ...
# 573127  2016A&A...591A..74D             1746       62        O  fulltext
# 573128  2016A&A...591A..74D             1746       62        O  fulltext
# 573129  2016A&A...591A..74D             1746       62        O  fulltext
# 573130  2016A&A...591A..74D             1746       62        O  fulltext
# 573131  2016A&A...591A..74D             1746       62        O  fulltext
#
#             tokens                          unique_id  sentence_id  \
# 0           Whilst   fulltext_487_2019MNRAS.486.5558S            0
# 1                a   fulltext_487_2019MNRAS.486.5558S            0
# 2       reasonable   fulltext_487_2019MNRAS.486.5558S            0
# 3         harmonic   fulltext_487_2019MNRAS.486.5558S            0
# 4              fit   fulltext_487_2019MNRAS.486.5558S            0
# ...            ...                                ...          ...
# 573127       level  fulltext_1746_2016A&A...591A..74D            0
# 573128         (RV  fulltext_1746_2016A&A...591A..74D            0
# 573129   intervals  fulltext_1746_2016A&A...591A..74D            0
# 573130          48  fulltext_1746_2016A&A...591A..74D            0
# 573131          km  fulltext_1746_2016A&A...591A..74D            0
#
#         sentence_id2
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 573127          2057
# 573128          2057
# 573129          2057
# 573130          2057
# 573131          2057
#
# [573132 rows x 9 columns]

# %% [markdown]
# #### Finding Sentences

# %%
df['is_stoptoken'] = 0
df['is_stoptoken'][df.tokens == '.'] = 1
# Out:
# /Users/anshul/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['sentence_id'] = df['is_stoptoken'].cumsum()

# %%
df
# Out:
#                     bibcode  label_studio_id  ner_ids ner_tags   section  \
# 0       2019MNRAS.486.5558S              487       62        O  fulltext
# 1       2019MNRAS.486.5558S              487       62        O  fulltext
# 2       2019MNRAS.486.5558S              487       62        O  fulltext
# 3       2019MNRAS.486.5558S              487       62        O  fulltext
# 4       2019MNRAS.486.5558S              487       62        O  fulltext
# ...                     ...              ...      ...      ...       ...
# 573127  2016A&A...591A..74D             1746       62        O  fulltext
# 573128  2016A&A...591A..74D             1746       62        O  fulltext
# 573129  2016A&A...591A..74D             1746       62        O  fulltext
# 573130  2016A&A...591A..74D             1746       62        O  fulltext
# 573131  2016A&A...591A..74D             1746       62        O  fulltext
#
#             tokens                          unique_id  is_stoptoken  \
# 0           Whilst   fulltext_487_2019MNRAS.486.5558S             0
# 1                a   fulltext_487_2019MNRAS.486.5558S             0
# 2       reasonable   fulltext_487_2019MNRAS.486.5558S             0
# 3         harmonic   fulltext_487_2019MNRAS.486.5558S             0
# 4              fit   fulltext_487_2019MNRAS.486.5558S             0
# ...            ...                                ...           ...
# 573127       level  fulltext_1746_2016A&A...591A..74D             0
# 573128         (RV  fulltext_1746_2016A&A...591A..74D             0
# 573129   intervals  fulltext_1746_2016A&A...591A..74D             0
# 573130          48  fulltext_1746_2016A&A...591A..74D             0
# 573131          km  fulltext_1746_2016A&A...591A..74D             0
#
#         sentence_id
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 573127         2057
# 573128         2057
# 573129         2057
# 573130         2057
# 573131         2057
#
# [573132 rows x 9 columns]

# %% [markdown]
# #### Finding length of a sentences

# %%
df.groupby('sentence_id').agg(count=('sentence_id', 'count')).describe()
# Out:
#              count
# count  2058.000000
# mean    278.489796
# std     359.095619
# min       4.000000
# 25%      53.250000
# 50%     139.000000
# 75%     348.000000
# max    2694.000000

# %%
len(df)
# Out:
# 573132

# %%
573132/10000
# Out:
# 57.3132

# %%
start_tokens = ['The', 'We', 'This', 'In', 'Figure', 'Fig.', 'For', 'Table', 'However,', 
                'As', 'These', 'It', 'To', 'Our', 'ACKNOWLEDGEMENTS', 'If', 'Galactic',
                'Department', 'All', 'Natutal', 'Collaboration', 'From', 'Space', 'Section'
]

# %%
sum(df['tokens'] == "Section")
# Out:
# 360

# %%
i = 0
all = []
for token in df.tokens:
    if token.endswith('.'):
        if '.' in token[:-1]:
            i +=1
            all.append(token)

# %%
set(all)
# Out:
# {'#2012.1.00437.S.',
#  '#2013.1.00601.S.',
#  '(0.001).',
#  '(0.6arcsec).',
#  '(1.0,0.1).',
#  '(1.140035.01).',
#  '(10.4%).',
#  '(6.4).',
#  '(>0.5).',
#  '(J.J.',
#  '(J.K.).',
#  '(J.P.).',
#  '(L.M.',
#  '(P.A.',
#  '(P.J.K).',
#  '(P.O.R.',
#  '(R.M.-D.',
#  '(S.A.A.).',
#  '(S.M.).',
#  '(cosmosnet.it).',
#  '(cschreib.github.io/phypp/).',
#  '(e.g.',
#  '(i.e.',
#  '(sky.esa.int/).',
#  '(Á.L.J.).',
#  '(∼1.5).',
#  ')=3.5.',
#  '+46d57m21.19s.',
#  '...',
#  '.true.',
#  '/1.4.',
#  '/d.o.f.',
#  '0.002.',
#  '0.003.',
#  '0.004′′).',
#  '0.005.',
#  '0.01.',
#  '0.017.',
#  '0.018.',
#  '0.01–0.60).',
#  '0.02.',
#  '0.025.',
#  '0.03.',
#  '0.039.',
#  '0.04.',
#  '0.043.',
#  '0.046.',
#  '0.07.',
#  '0.08).',
#  '0.1).',
#  '0.1.',
#  '0.10.3.',
#  '0.11.',
#  '0.116.',
#  '0.12.',
#  '0.15).',
#  '0.18.',
#  '0.19).',
#  '0.1–0.2.',
#  '0.2%.',
#  '0.2.',
#  '0.21.',
#  '0.24.',
#  '0.256.',
#  '0.27.',
#  '0.29.',
#  '0.2].',
#  '0.30.',
#  '0.31.',
#  '0.33%.',
#  '0.37).',
#  '0.38.',
#  '0.3G.',
#  '0.4.',
#  '0.42).',
#  '0.428.',
#  '0.43.',
#  '0.43].',
#  '0.44.',
#  '0.450.',
#  '0.48.',
#  '0.49).',
#  '0.49.',
#  '0.4–0.6.',
#  '0.5%.',
#  '0.5).',
#  '0.5.',
#  '0.52.5.',
#  '0.54.',
#  '0.55).',
#  '0.5].',
#  '0.5au.',
#  '0.5percent.',
#  '0.5–0.55.',
#  '0.6).',
#  '0.6.',
#  '0.6...99.',
#  '0.61].',
#  '0.62.',
#  '0.68.',
#  '0.6°.',
#  '0.7.',
#  '0.70.',
#  '0.73.',
#  '0.75.',
#  '0.79°).',
#  '0.7–0.8.',
#  '0.8.',
#  '0.82).',
#  '0.846(3).',
#  '0.86.',
#  '0.9%.',
#  '0.9%−1.7%.',
#  '0.9).',
#  '0.9.',
#  '0.95.',
#  '05.65.',
#  '087.A-0514.',
#  '088.C-0892(A).',
#  '088.C-0898.',
#  '090.C-0125(A).',
#  '092.A-0170.',
#  '093.B-0932(A).',
#  '094.A-0525(A).',
#  '094.B-0061(C)).',
#  '094.B-0061).',
#  '099.C-0728.',
#  '1.0.',
#  '1.03.',
#  '1.05.01.88.04.',
#  '1.05.01.94.02.',
#  '1.05.01.94.05.',
#  '1.1.',
#  '1.1.1.1/16/A/213.',
#  '1.15).',
#  '1.1–1.5.',
#  '1.25.',
#  '1.3.',
#  '1.30.',
#  '1.5.',
#  '1.5keV.',
#  '1.67.',
#  '1.69).',
#  '1.7.',
#  '1.783.',
#  '1.788.',
#  '1.875.',
#  '1.9.',
#  '10.0m.',
#  '12.5.',
#  '13.0.',
#  '13.5%).',
#  '1358/19.2).',
#  '175.A-0839.',
#  '177.A-3018.',
#  '177.D-3023(C).',
#  '179.A-2004.',
#  '179.A-2006.',
#  '179.B-2003.',
#  '18.5arcsec.',
#  '188.B-3002.',
#  '188.D-3003.',
#  '191.D-0255.',
#  '195.12.',
#  '196.B-0578.',
#  '1–1.5.',
#  '2.0.',
#  '2.1.',
#  '2.1.2.',
#  '2.1057.',
#  '2.1058.',
#  '2.1059.',
#  '2.2.',
#  '2.2.1.',
#  '2.25.',
#  '2.3%.',
#  '2.3.',
#  '2.35.',
#  '2.36.',
#  '2.4.',
#  '2.40.',
#  '2.4–2.6.',
#  '2.5%.',
#  '2.5.',
#  '2.5σ.',
#  '2.6.',
#  '2.7.',
#  '2.94.',
#  '2013.1.00312.S.',
#  '2013.1.00710.S.',
#  '2013.1.01020.S.',
#  '2014.0048).',
#  '2015-038-R.0.',
#  '2015.0.',
#  '2015.1.00956.S.',
#  '2016.1.01164.S.',
#  '2017-14-H.0.',
#  '2017.1.00492.S.',
#  '21.2.',
#  '22.5).',
#  '23.0.',
#  '24.15.',
#  '3.0.',
#  '3.0σ.',
#  '3.1.',
#  '3.19.',
#  '3.2).',
#  '3.2.',
#  '3.2.1.',
#  '3.2.2.',
#  '3.3).',
#  '3.3.',
#  '3.3.2.',
#  '3.4.',
#  '3.5.',
#  '3.5.2.',
#  '3.5.4.',
#  '3.52.',
#  '3.6.',
#  '3.8.',
#  '3.9.',
#  '34.5.',
#  '340.S.',
#  '382.C-0195(A).',
#  '3933.7.',
#  '3–6.5.',
#  '4.1.',
#  '4.1.1.',
#  '4.1.2.',
#  '4.1.3.',
#  '4.1.4.',
#  '4.2.',
#  '4.2.1.',
#  '4.2.2).',
#  '4.2.2.',
#  '4.2.3.',
#  '4.3.',
#  '4.3.1.',
#  '4.4.',
#  '4.5).',
#  '4.5.',
#  '4.6.',
#  '4.68).',
#  '4.7.',
#  '4.8).',
#  '4.85GHz.',
#  '44.5−45.',
#  '5.1.',
#  '5.1.2.',
#  '5.1.3.',
#  '5.2.',
#  '5.2.1.',
#  '5.2.11.',
#  '5.3.',
#  '5.3.1.',
#  '5.4.',
#  '5.5).',
#  '5.5.',
#  '5.6.',
#  '5C4.152.',
#  '6.1.',
#  '6.1.4.',
#  '6.2.',
#  '6.2.2.',
#  '6.2.3.',
#  '6.2.4.',
#  '6.3.',
#  '6.37.341.2015.',
#  '6.4.',
#  '6.5.',
#  '614.001.209.',
#  '614.001.352.',
#  '614.001.552.',
#  '621.016.402.',
#  '628.002.002).',
#  '639.042.422).',
#  '639.043.409.',
#  '639.043.513.',
#  '648.000.030).',
#  '66.3407.',
#  '67.177-21/2016.',
#  '7.1.',
#  '7.1.3.',
#  '7.2.',
#  '7.3.',
#  '7.3].',
#  '7.4.',
#  '8.0-9.2).',
#  '8.1.',
#  '8.2.',
#  '8.35.',
#  '8.5.',
#  '8.9.',
#  '88881.120856/2016-01.',
#  '9.2.',
#  '9.25.',
#  '91.C-0768(A).',
#  '97.2%).',
#  'A.1.',
#  'A.2.',
#  'A.2320.0076.',
#  'A.3.',
#  'A.3.2.',
#  'A.A.',
#  'A.A.-H.',
#  'A.B.',
#  'A.B.M.',
#  'A.C.',
#  'A.C.N.Q.',
#  'A.C.R.',
#  'A.C.S.',
#  'A.D.',
#  'A.D.C.',
#  'A.D.W.',
#  'A.E.',
#  'A.F.',
#  'A.F.J.M.',
#  'A.F.L.',
#  'A.G.E.',
#  'A.G.R.',
#  'A.H.',
#  'A.I.Z.',
#  'A.J.',
#  'A.J.B.',
#  'A.J.D.',
#  'A.K.',
#  'A.K.H.K.',
#  'A.K.L.',
#  'A.L.',
#  'A.L.C.',
#  'A.L.S.',
#  'A.M.',
#  'A.M.B.',
#  'A.M.D.',
#  'A.M.D.).',
#  'A.M.H.',
#  'A.M.M.',
#  'A.N.',
#  'A.N.D.',
#  'A.N.Y.',
#  'A.P.',
#  'A.P.S.H.',
#  'A.P.i.',
#  'A.P.o.',
#  'A.Q.',
#  'A.R.',
#  'A.R.C.',
#  'A.R.L.',
#  'A.S.',
#  'A.S.-M.',
#  'A.S.M.',
#  'A.T.',
#  'A.U.',
#  'A.U.L.',
#  'A.V.',
#  'A.V.F.',
#  'A.Z.',
#  'A0.99f.',
#  'ADS/JAO.ALMA#2011.0.00419.S.',
#  'ADS/JAO.ALMA#2013.1.00092.S.',
#  'ADS/JAO.ALMA#2013.1.00220.S.',
#  'ADS/JAO.ALMA#2013.1.00226.S.',
#  'ADS/JAO.ALMA#2013.1.00278.S.',
#  'ADS/JAO.ALMA#2013.1.00449.S.',
#  'ADS/JAO.ALMA#2013.1.00710.S.',
#  'ADS/JAO.ALMA#2015.1.00003.S.',
#  'ADS/JAO.ALMA#2015.1.00582.S.',
#  'ADS/JAO.ALMA#2015.1.00598.S.',
#  'ADS/JAO.ALMA#2015.1.00773.S.',
#  'ADS/JAO.ALMA#2015.1.01025.S.',
#  'ADS/JAO.ALMA#2016.1.00459.S.',
#  'ADS/JAO.ALMA#2017.1.00124.S.',
#  'ADS/JAO.ALMA#[2015.1.00878.7].',
#  'ADS/JAO.ALMA2016.1.00413.V.',
#  'AGALG331.3873−0.360.',
#  'ALMA#2016.1.00074.S.',
#  'B.).',
#  'B.1.',
#  'B.2.',
#  'B.3.',
#  'B.6.',
#  'B.7.',
#  'B.8.',
#  'B.A.',
#  'B.A.M.',
#  'B.B.',
#  'B.B.Z.',
#  'B.C.',
#  'B.D.',
#  'B.D.P.',
#  'B.M.G.',
#  'B.M.V.',
#  'B.N.',
#  'B.P.',
#  'B.R.G.',
#  'B.S.',
#  'B.T.',
#  'B.T.P.',
#  'B.W.',
#  'B.Z.',
#  'C.1.',
#  'C.3.',
#  'C.A.H.',
#  'C.A.L.',
#  'C.B.',
#  'C.C.',
#  'C.C.-G.',
#  'C.D.',
#  'C.D.M.',
#  'C.D.P.',
#  'C.D.W.',
#  'C.E.C.',
#  'C.F.',
#  'C.F.M.',
#  'C.G.',
#  'C.G.M.',
#  'C.J.N.',
#  'C.K.',
#  'C.L.',
#  'C.M.',
#  'C.M.C.',
#  'C.M.H.',
#  'C.M.T.',
#  'C.N.S.',
#  'C.P.',
#  'C.P.G.',
#  'C.R.',
#  'C.R.A.',
#  'C.R.K.',
#  'C.R.S.',
#  'C.S.',
#  'C.S.K.',
#  'C.W.',
#  'C.W.O.',
#  'C.W.S.',
#  'C.Y.H.',
#  'CIC-UMSNH-4.9.',
#  'D.A.D.',
#  'D.A.G.',
#  'D.A.U.',
#  'D.B.',
#  'D.C.L.',
#  'D.F.M.',
#  'D.G.',
#  'D.H.',
#  'D.J.',
#  'D.J.S.',
#  'D.K.',
#  'D.L.',
#  'D.M.',
#  'D.M.C.',
#  'D.O.J.',
#  'D.P.',
#  'D.P.H.',
#  'D.R.',
#  'D.R.G.S.',
#  'D.R.P.',
#  'D.R.W.',
#  'D.S.',
#  'D.U.',
#  'D.W.',
#  'D.W.L.',
#  'E-26/111.488/2013).',
#  'E.B.',
#  'E.E.M.',
#  'E.E.V.',
#  'E.G.',
#  'E.G.Z.',
#  'E.H.',
#  'E.I.',
#  'E.J.Z.',
#  'E.K.',
#  'E.M.R.',
#  'E.N.E.',
#  'E.P.',
#  'E.Q.',
#  'E.R.',
#  'E.R.C.',
#  'E.S.',
#  'E.T.',
#  'E.V.',
#  'E.V.Q.',
#  'E.W.P.',
#  'E.Y.H.',
#  'E.Z.',
#  'E.v.D.',
#  'F.-K.',
#  'F.4-5(137-FRP)/2014(BSR).',
#  'F.A.-S.',
#  'F.B.',
#  'F.C.',
#  'F.D.',
#  'F.F.',
#  'F.G.X.',
#  'F.J.C.',
#  'F.L.',
#  'F.M.',
#  'F.P.',
#  'F.R.).',
#  'F.S.',
#  'F.S.E.',
#  'F.T.',
#  'F.U.',
#  'F.V.',
#  'F.Y.',
#  'F.v.d.B.',
#  'FP7-IDEAS-Phys.LSS.',
#  'Fig.1.',
#  'G.-F.',
#  'G.A.',
#  'G.A.W.',
#  'G.B.',
#  'G.B.R.',
#  'G.C.',
#  'G.C.P.',
#  'G.C.S.',
#  'G.D.',
#  'G.F.',
#  'G.G.K.',
#  'G.H.',
#  'G.J.H.',
#  'G.L.',
#  'G.M.',
#  'G.M.-P.',
#  'G.M.K.',
#  'G.M.M.C.).',
#  'G.N.',
#  'G.P.',
#  'G.S.',
#  'G.S.C.',
#  'G.S.K.',
#  'G.V.',
#  'G.W.',
#  'G.W.H.',
#  'G.W.L.',
#  'G.Y.',
#  'G10.6-0.4.',
#  'G330.2+1.0.',
#  'G331.31–00.34.',
#  'GO-12065.01-A.',
#  'H.-T.J.',
#  'H.-W.R.',
#  'H.A.V.',
#  'H.C.H.',
#  'H.J.',
#  'H.J.M.',
#  'H.K.',
#  'H.L.',
#  'H.M.',
#  'H.M.V.',
#  'H.Res.',
#  'H.T.',
#  'H.V.',
#  'HST-GO-14268.022-A.',
#  'I-1362-303.7/2016).',
#  'I.C.',
#  'I.G.',
#  'I.G.-B.',
#  'I.H.',
#  'I.H.C.',
#  'I.J.-S.',
#  'I.M.',
#  'I.R.',
#  'I.S.R.',
#  'II.16.',
#  'J.-B.D.',
#  'J.-J.',
#  'J.-P.',
#  'J.-Y.',
#  'J.-h.',
#  'J.A.',
#  'J.A.-G.',
#  'J.A.J.',
#  'J.A.L.',
#  'J.A.T.',
#  'J.B.',
#  'J.B.C.',
#  'J.B.M.',
#  'J.B.T.',
#  'J.C.A.',
#  'J.C.L.',
#  'J.D.A.-G.',
#  'J.F.',
#  'J.F.B.',
#  'J.F.G.',
#  'J.F.L.',
#  'J.G.',
#  'J.H.',
#  'J.H.K.',
#  'J.H.L.',
#  'J.H.W.',
#  'J.I.G.H.',
#  'J.J.',
#  'J.J.D.',
#  'J.J.G.',
#  'J.K.',
#  'J.K.F.',
#  'J.K.J.',
#  'J.K.J.).',
#  'J.K.T.',
#  'J.L.',
#  'J.L.N.C.',
#  'J.L.P.',
#  'J.L.T.',
#  'J.M.',
#  'J.M.A.',
#  'J.M.D.',
#  'J.M.D.K.',
#  'J.M.G.',
#  'J.M.S.',
#  'J.N.',
#  'J.O.',
#  'J.P.',
#  'J.P.B.',
#  'J.P.L.',
#  'J.P.O.',
#  'J.P.W.',
#  'J.R.',
#  'J.R.A.D.',
#  'J.R.M.',
#  'J.S.',
#  'J.S.-B.',
#  'J.S.S.',
#  'J.T.',
#  'J.T.A.',
#  'J.W.',
#  'J.W.R.',
#  'J.W.T.H.',
#  'J.W.X.',
#  'J0523.3−2527.',
#  'J090552.41+025931.5.',
#  'J105327.2+205836.',
#  'J1417.5–4402.',
#  'J1856.5−3754).',
#  'JAO.ALMA.2016.1.01236.S.',
#  'K.B.',
#  'K.C.',
#  'K.C.W.',
#  'K.E.K.',
#  'K.F.',
#  'K.H.',
#  'K.I.',
#  'K.J.S.',
#  'K.Kifonidis.',
#  'K.L.P.',
#  'K.M.',
#  'K.M.H.',
#  'K.P.',
#  'K.P.R.',
#  'K.R.C.',
#  'K.W.',
#  'K.Z.',
#  'K.Z.A.-C.',
#  'K.Z.S.',
#  'L.A.',
#  'L.C.',
#  'L.C.H.',
#  'L.F.',
#  'L.G.',
#  'L.I.',
#  'L.K.',
#  'L.K.H.',
#  'L.L.',
#  'L.M.',
#  'L.M.M.',
#  'L.M.O.',
#  'L.P.',
#  'L.R.-D.',
#  'L.S.',
#  'L.T.',
#  'L.Z.',
#  'M.-R.W.',
#  'M.A.',
#  'M.A.A.',
#  'M.A.G.',
#  'M.A.M.',
#  'M.B.',
#  'M.B.A.',
#  'M.C.',
#  'M.C.A.',
#  'M.C.B.',
#  'M.D.',
#  'M.F.',
#  'M.G.',
#  'M.G.L.',
#  'M.G.W.',
#  'M.H.',
#  'M.I.D.',
#  'M.J.',
#  'M.J.G.',
#  'M.J.R.',
#  'M.J.W.',
#  'M.K.',
#  'M.L.',
#  'M.L.G.',
#  'M.L.N.',
#  'M.L.W.',
#  'M.M.',
#  'M.M.M.L.',
#  'M.N.',
#  'M.N.D.',
#  'M.O.',
#  'M.P.',
#  'M.P.-S.',
#  'M.P.E.',
#  'M.P.H.',
#  'M.Pi.',
#  'M.R.',
#  'M.R.B.',
#  'M.R.H.',
#  'M.S.',
#  'M.S.O.',
#  'M.S.P.',
#  'M.T.',
#  'M.T.M.',
#  'M.U.K.',
#  'M.V.',
#  'M.V.P.',
#  'M.Š.',
#  'M0.0AD10.0.',
#  'M3.B.',
#  'N.A.',
#  'N.C.',
#  'N.D.',
#  'N.F.',
#  'N.G.',
#  'N.H.B.',
#  'N.J.C.',
#  'N.K.',
#  'N.L.',
#  'N.M.',
#  'N.M.M.G.',
#  'N.M.N.',
#  'N.P.',
#  'N.S.',
#  'N.T.',
#  'N.T.P.',
#  'N.W.M.',
#  'No.2014-037-R.0.',
#  'O.C.',
#  'O.C.J.',
#  'O.K.',
#  'O.L.F.',
#  'O.M.',
#  'O.P.',
#  'O.R.L.',
#  'O.V.',
#  'P.A.',
#  'P.A.B.',
#  'P.B.T.',
#  'P.C.',
#  'P.D.',
#  'P.E.',
#  'P.E.N.',
#  'P.G.',
#  'P.H.',
#  'P.H.H.',
#  'P.I.',
#  'P.J.',
#  'P.K.G.W.',
#  'P.M.K.',
#  'P.M.W.',
#  'P.N.',
#  'P.O.P.',
#  'P.P.',
#  'P.R.',
#  'P.R.W.',
#  'P.R.Y.',
#  'P.V.D.',
#  'Ph.D.',
#  'Q.-S.',
#  'Q24.5.',
#  'R.-S.L.',
#  'R.A.',
#  'R.A.F.',
#  'R.A.–decl.',
#  'R.B.',
#  'R.C.',
#  'R.C.R.',
#  'R.D.',
#  'R.D.G.',
#  'R.E.',
#  'R.E.C.',
#  'R.G.',
#  'R.G.B.',
#  'R.G.L.',
#  'R.G.M.',
#  'R.H.B.',
#  'R.H.W.',
#  'R.I.D.',
#  'R.J.',
#  'R.J.F.',
#  'R.J.Ivison).',
#  'R.J.M.',
#  'R.J.S.',
#  'R.K.',
#  'R.K.S.',
#  'R.L.',
#  'R.M.',
#  'R.N.',
#  'R.O.',
#  'R.R.',
#  'R.R.R.',
#  'R.S.',
#  'R.S.E.',
#  'R.S.K.',
#  'R.S.S.V.',
#  'R.T.',
#  'R.W.',
#  'R.Z.',
#  'R.d.G.',
#  'S.-P.M.',
#  'S.A.',
#  'S.B.',
#  'S.B.C.',
#  'S.C.',
#  'S.C.C.B.',
#  'S.C.Y.',
#  'S.D.',
#  'S.D.L.P.',
#  'S.E.H.',
#  'S.E.R.',
#  'S.F.',
#  'S.F.H.',
#  'S.G.',
#  'S.G.-B.',
#  'S.G.G.',
#  'S.G.S.',
#  'S.H.',
#  'S.H.L.',
#  'S.K.',
#  'S.L.',
#  'S.L.F.',
#  'S.M.',
#  'S.M.C.',
#  'S.M.H.',
#  'S.N.',
#  'S.N.R.',
#  'S.O.',
#  'S.P.',
#  'S.P.Q.',
#  'S.R.',
#  'S.R.-F.',
#  'S.S.',
#  'S.S.-D.',
#  'S.V.',
#  'S.W.A.',
#  'S.W.J.',
#  'SAXJ1808.43658.',
#  'SJ0.2-EH).',
#  'Sco.).',
#  'T.A.',
#  'T.B.',
#  'T.C.B.',
#  'T.D.',
#  'T.D.-S.',
#  'T.D.M.',
#  'T.E.',
#  'T.F.',
#  'T.G.',
#  'T.G.P.',
#  'T.J.M.',
#  'T.K.G.',
#  'T.M.',
#  'T.M.D.',
#  'T.M.T.',
#  'T.N.',
#  'T.N.-C.',
#  'T.P.',
#  'T.R.',
#  'T.S.',
#  'T.S.R.',
#  'T.T.',
#  'T.W.',
#  'T.W.-S.H.',
#  'TOP1.16.057.',
#  'U.H.',
#  'U.K.',
#  'U.S.',
#  'V.A.',
#  'V.B.',
#  'V.B.-R.',
#  'V.D.',
#  'V.F.',
#  'V.K.',
#  'V.L.',
#  'V.L.K.',
#  'V.P.D.',
#  'V.S.',
#  'V.S.P.',
#  'V.W.',
#  'W.C.',
#  'W.E.K.',
#  'W.F.',
#  'W.J.',
#  'W.M.',
#  'W.P.L.',
#  'W.R.P..',
#  'W.T.B.',
#  'W.W.',
#  'W.Y.',
#  'W.Z.',
#  'X.F.',
#  'X.K.',
#  'X.W.',
#  'X.W.L.',
#  'Y.-H.',
#  'Y.-L.',
#  'Y.-M.',
#  'Y.-W.T.',
#  'Y.B.',
#  'Y.C.',
#  'Y.H.',
#  'Y.J.',
#  'Y.L.',
#  'Y.O.',
#  'Y.P.',
#  'Y.S.',
#  'Y.S.T.',
#  'Y.T.',
#  'Y.T.L.',
#  'Y.W.W.',
#  'Y.Y.M.',
#  'Z.C.M.',
#  'Z.H.',
#  'Z.L.',
#  '[0,0.95).',
#  '[Mn/Fe]...',
#  '[e.g.',
#  'a.m.u.',
#  'atchekho@northwestern.edu.',
#  'c.l.',
#  'code.google.com/p/healpy).',
#  'comm.).',
#  'e.V.',
#  'e.g.',
#  'e.s.u.',
#  'etc.).',
#  'exoplanet.eu.',
#  'exoplanets.org.',
#  'http://www.sdss.org/.',
#  'http://www.tacc.utexas.edu.',
#  'i.e.',
#  'l.3.1.).',
#  'l.o.s.',
#  'm.i.s.',
#  'n.2017-13-H.0.',
#  'n.2017-14-H.0).',
#  'n.2017-14-H.0.',
#  'n.2018-23-HH.0.',
#  'no.714196.',
#  'prep.).',
#  'r.m.s.',
#  'ref.no.',
#  'w.r.t.',
#  '~0.5.',
#  'λ1347.23.',
#  '–2.5.',
#  '“...',
#  '−0.008.',
#  '−0.14.',
#  '−0.86.',
#  '−1.2.',
#  '−1.5).',
#  '−1.5.',
#  '−1.7.',
#  '−18.4.',
#  '−19.0.',
#  '−2.0.',
#  '−2.4.',
#  '−2.5.',
#  '−2.8.',
#  '−3.0).',
#  '−3.5.',
#  '−5.2.',
#  '−5.6.',
#  '∼0.02.',
#  '∼0.7.',
#  '∼1.1.',
#  '∼1.5.',
#  '∼1.7.',
#  '∼2.08.',
#  '∼2.25.',
#  '∼2σ–2.5σ.',
#  '∼7.8–8.3.',
#  '≈0.23.',
#  '≲−4.45).'}

# %%
i
# Out:
# 31382

# %%
len(df)
# Out:
# 573132

# %%
573132/31382
# Out:
# 18.263080746924988

# %%
j = 0
for token in df.tokens:
    if '.' in token:
        j +=1

# %%
j
# Out:
# 36223

# %%
k = 0
all = []
for token in df.tokens:
    if ('.' in token) and (not token.endswith('.')):
        k +=1
        all.append(token)

# %%
k
# Out:
# 4841

# %%
set(all)
# Out:
# {'2.4',
#  '7774.16',
#  'http://rms.leeds.ac.uk/cgi-bin/public/RMS_DATABASE.cgi',
#  '88.7',
#  'AGNs—e.g.,',
#  '7775.39',
#  '0.979855(5)',
#  '0.847',
#  'A.17',
#  '(i.e.,',
#  '0.74',
#  '0.98',
#  '(5.4',
#  '86.24',
#  '6.8',
#  '0.4kpc',
#  'v5.1.1;',
#  '1.90',
#  '(M.B.,',
#  '0.1184,',
#  '179.B-2002,',
#  '0.47–0.82',
#  '0.5]',
#  '0.54',
#  '13.3,',
#  '1.516',
#  '11.2/3.3',
#  'P.J.K.,',
#  '0.92–0.95,',
#  'L.P.Y.,',
#  'M.Š.)',
#  '0.4),',
#  'https://doi.org/10.17909/t9-ge0b-jm58',
#  '−1.3',
#  '0.65',
#  '19.93',
#  '0.02)',
#  '70.C-0008(A)',
#  'xlink:href="aa37995-20-eq62.gif"></inline-graphic>',
#  '≈0.5',
#  'http://szcluster-db.ias.u-psud.fr',
#  'B.4',
#  '3.0)',
#  '(0.99),',
#  '6.37)',
#  '0.91',
#  '20.3',
#  '0.16',
#  'J.E.L.’s',
#  '1547.0-5408,',
#  '−1.5',
#  'A.32',
#  '0.17,',
#  '6749.4',
#  'xlink:href="apj523559ieqn106.gif"></inline-graphic>',
#  '1.16',
#  'medium.”',
#  'A.33',
#  '“rot-ST.”',
#  '1.49',
#  '0.70',
#  '0.117222',
#  '0.65′′',
#  '1843.1',
#  '0.01',
#  '(0.000,',
#  '0.15',
#  '21.5',
#  '10.5281/zenodo.11813',
#  'C.R.),',
#  '(0.95)',
#  '(8.5',
#  '2.30',
#  '1.93-m',
#  'A.4',
#  '6.942',
#  'http://www.gama-survey.org/',
#  'H.V.,',
#  'http://cxc.harvard.edu/ciao/',
#  '5172.7',
#  '−0.25',
#  '(0.3–1)',
#  '0.77',
#  '3.8',
#  '∼0.3',
#  '669.6',
#  '17.67,',
#  '0.16)',
#  '0.524',
#  '0.48',
#  '2.81',
#  '31.4',
#  'http://www.cosmos.esa.int/web/gaia/dpac/consortium',
#  '56937.81',
#  '1.52',
#  '0.01°',
#  '1.5–1.8',
#  'G331.34−00.36',
#  'www.star.bris.ac.uk/∼mbt/stilts',
#  'A.6',
#  '(healpix.jpl.nasa.gov,',
#  '(1.69)',
#  '(0.28',
#  'MD-7355.2015.2,',
#  '106-2112-M-008-019-(Y.J.C.)',
#  '0.3percent',
#  '0.14,',
#  'J023951.88−013558.0,',
#  '(4.3',
#  'S.p.A,',
#  '(3.4',
#  '106.4',
#  '14.33%',
#  '0.903',
#  '0.112–0.360,',
#  '27.38',
#  'orbit.)',
#  '5808.32',
#  '(1.2',
#  '−3.3',
#  '0.56%',
#  '0.028',
#  '0.739',
#  'http://simbad.u-strasbg.fr/simbad/',
#  'FP7-IDEAS-Phys.LSS',
#  '3.41',
#  '9.5',
#  'http://www.matplotlib.org/',
#  '3.13',
#  'http://www.gama-survey.org',
#  'Á.B.,',
#  '134/304.5',
#  '2.73K',
#  '(287.57,76.77)',
#  '5(±0.5)°',
#  '−29.0°',
#  '3.0,',
#  'clean.py,',
#  '1.0e11',
#  'E.P.);',
#  '−0.09',
#  '(29.5',
#  '12.8',
#  '18.7',
#  '∼121.48',
#  '0.369',
#  'J0523.3−2530,',
#  'HST-HF-51333.01-A',
#  'J0523.5−2529',
#  'matplotlib.org',
#  '∼0.5–0.75',
#  '0.41',
#  '~3.5,',
#  '0.704,',
#  'D.R.G.S.,',
#  '2.5-metre',
#  'T.T.,',
#  '09h01m09.225s,',
#  '(P.J.A.S.,',
#  '0.47)',
#  'simulations.)',
#  '14.1',
#  '1.22.2kms',
#  '10.0',
#  '0.0046',
#  '40.7',
#  '(M0.0AD3.0,',
#  'S.B.,',
#  '6.6,',
#  'http://edd.ifa.hawaii.edu/index.html',
#  '1.8',
#  '60.80',
#  '1.414,',
#  '3.00',
#  '0.8Hz',
#  '10.9',
#  '1–1.2',
#  '53.0',
#  '3.2',
#  '0.71',
#  '000.0',
#  '17.94',
#  'form.)',
#  '1.5–2.0',
#  '2.2.1',
#  'http://research.cs.wisc.edu/htcondor/',
#  '−0.9',
#  '89.9–91.9',
#  '(3.8',
#  'https://almascience.eso.org/aq/',
#  '2.2,',
#  '(V.M.N.)',
#  'xmlns:mml="http://www.w3.org/1998/Math/MathML"',
#  'http://n2t.net/ark:/85065/d7wd3xhc',
#  '0.0005',
#  'H.R.,',
#  '0.1–158.48',
#  '7.7,',
#  '1.25',
#  '30.5',
#  '(F.E.B.,',
#  '1.344',
#  '20.6,',
#  '−3.0,',
#  'No.:',
#  '3.1.8',
#  '(0.65',
#  '(2.15',
#  '∼3.1',
#  '−2.50°)',
#  '0.25%',
#  '6.8682',
#  'Z.M.,',
#  '−1.5)',
#  'J164449.3+573451,',
#  'Universe.”',
#  '−0.87',
#  'A.21',
#  '[0.5–2]',
#  '1.34',
#  '0.055)',
#  '42.65',
#  '0.64',
#  '0.034',
#  '1.74',
#  'ribbons.”',
#  '0.4857',
#  '0.28,',
#  '(0.2)',
#  '≤0.01',
#  '−1.5,',
#  '8.3',
#  '1.416',
#  '∼1.8',
#  'viz.,',
#  'universe.”',
#  '0.32',
#  '4.50,',
#  '∼1.4',
#  'HST-HF2-51372.001',
#  '11.31,',
#  '0.1pc',
#  '(T.0100.15),',
#  '3.0–8.0',
#  '12.7,',
#  '43.65)',
#  '2.810',
#  '1.0938,',
#  '2.3.1',
#  '0.56Hz,',
#  'C.1',
#  '29.2',
#  '0.17',
#  'A1.3',
#  '5.04°)',
#  'http://www.numpy.org/',
#  'HF-51348.001',
#  '0.87,',
#  '−1.1),',
#  'J.J.,',
#  '∼10.1',
#  'adi_Z=0.02_Lr=90au_a=3mm',
#  '614.001.451,',
#  'http://www.cosmos.esa.int/gaia',
#  '1.05,',
#  'A.38',
#  '(99.47%',
#  '–0.15',
#  'https://www.rave-survey.org',
#  '0.37',
#  '0.24,',
#  '∼0.7',
#  '0.66',
#  '1.8–2.2',
#  'V.S.),',
#  '175.A-0839',
#  '340.S',
#  'J1753.5−0127',
#  '2.60),',
#  '0.24',
#  '556.936',
#  '1.06',
#  'i.e.:',
#  'www.ska.ac.za',
#  '(0.11',
#  '1.32,',
#  '0.2602',
#  '±0.04',
#  '−0.24',
#  '[0.04–0.09]',
#  'A.31',
#  '∼0.62',
#  '6.64',
#  '12.4',
#  '70.11',
#  '(0.26,',
#  '0.75',
#  'www.dirac.ac.uk',
#  '2.2–9.7',
#  '6.2',
#  '+0.5',
#  'gaiadr2.vari_rrlyrae;',
#  'https://github.com/keflavich/molecular_hydrogen',
#  '-HF2-51341.001-A',
#  '4.5),',
#  '349.1070',
#  '1.9),',
#  '(0.54',
#  '8.2,',
#  'https://cran.r-project.org/web/packages/ppcor/',
#  'https://www.cosmos.esa.int/web/gaia/dpac/consortium',
#  '3.56',
#  'A.15',
#  '193.51',
#  '(∼0.2',
#  '−3.8',
#  'E.M.,',
#  'SAXJ1808.43658',
#  '0.15,',
#  '0.002,',
#  'http://space.mit.edu/CXC/MARX/',
#  '0.109',
#  '5.8',
#  'A.20',
#  '8.3,',
#  'velocity.where',
#  '1.881',
#  '2.808',
#  '(1.250',
#  '2.04',
#  'J.-A.Z.,',
#  '(black).Here,',
#  'constant.)',
#  'http://www.sidc.be/silso/',
#  '−2.93;',
#  '9.3),',
#  '7.3),',
#  '17.65,',
#  '1.33',
#  'X9.3-class',
#  '1.93',
#  '0.30,',
#  '1.85',
#  '193.51/',
#  'http://www.astropy.org',
#  '4.́5',
#  'A.1',
#  '(O.M.,',
#  '−0.32',
#  '2.1-m',
#  '4.6.1',
#  '096.C-0249,',
#  "L.M.C.'s",
#  '0.1–2.4',
#  '1.27',
#  'J318.5338-22.8603',
#  'https://www.youtube.com/watch?v=_Ssc1GsqHds',
#  '3933.7',
#  '0.6,',
#  '0.1112620426,',
#  '(81.85°),',
#  '17.4',
#  '2.70',
#  '2012.1.00650.S,',
#  '(2.5',
#  'https://universe.bits-pilani.ac.in/Hyderabad/sbanik/EoS',
#  '-HF2-51383.001',
#  '21.6',
#  '8.75',
#  'https://www.cosmos.esa.int/gaia',
#  '25.99',
#  '[5.7,',
#  'www.astro.yale.edu/smarts/xrb/home.php',
#  '0.10,',
#  'L.Hdepohl,',
#  '3.6,',
#  '(7.0',
#  '−0.0017',
#  'http://archive.stsci.edu/hst/',
#  '0.4–1.0,',
#  'https://www.eaobservatory.org/jcmt/2019/08/new-ip-models-for-pol2-data/',
#  '13.5',
#  '(v1.5.1,',
#  '21.8%',
#  '99.5',
#  '0.00',
#  '1.548,',
#  'MACSJ1149.5+2223',
#  '0.5dex',
#  '7.16,',
#  '0.045',
#  '2.5',
#  'M0.0AD3.0',
#  '1.05.01.88.04',
#  '11.9',
#  '(=1.061)',
#  '342.729796',
#  '410.25,',
#  '0.3–0.7',
#  '4.9',
#  '93.4',
#  '3.6.8',
#  '1.04',
#  '−1.4',
#  '0.1',
#  'i.e.,Furthermore,',
#  '0.600,',
#  '(∼0.6;',
#  '(3.0',
#  '093.B-0693',
#  '0.6...2',
#  '3.510',
#  '2.48',
#  '∼0.1–0.3',
#  '177.A-3016,',
#  'significance.In',
#  '0.7),',
#  '1.55,',
#  '–0.7',
#  '−0.17',
#  '[0.15,',
#  '(0.59',
#  '0.02–0.09',
#  '0.61',
#  '94.3)',
#  '0.2,',
#  'G10.2-0.3,',
#  '[0.1,',
#  '7.4',
#  '−0.006',
#  '≈0.3',
#  'http://ds9.si.edu/site/Home.html',
#  '0.8,',
#  '13.6',
#  '.)',
#  'ePN.S',
#  '5.2.1',
#  '0.056;',
#  '4.56',
#  '∼0.8,',
#  '5.2.4',
#  '3.1.7',
#  '0.3:',
#  '5.656,',
#  '15:35:48.8',
#  '2−2.5',
#  '600.0',
#  'S.M.,',
#  '8.8',
#  '2.00',
#  'ADS/JAO.ALMA#[2015.1.01572.S]',
#  '≈0.02',
#  'https://antares.noao.edu',
#  '1.51',
#  'I.R.,',
#  '0.69',
#  '-HF2-51379.001-A',
#  '0.01,',
#  '5.3',
#  '43.5',
#  'gravity.’',
#  '0.84−0.94',
#  '19.3',
#  '4.5:',
#  'B.7',
#  'https://science.nrao.edu/facilities/vla/docs/manuals/obsguide/modes/pol',
#  '5.1.2',
#  '2.67',
#  '0.84',
#  '264.2',
#  '0.29',
#  '4.3',
#  '2.23),',
#  'I.N.,',
#  '4.2-m',
#  '2.778',
#  '96.6%,',
#  '18.49',
#  '0.00.4',
#  '0.58',
#  'J1417.5–4402,',
#  '(3.3',
#  '4.0',
#  '5.49',
#  '52.5',
#  '0.039',
#  '0.09',
#  '2,2.2',
#  '9.2%,',
#  '081.C-0833,',
#  '2.5D',
#  '#51311.01',
#  '0.5Myr',
#  'http://dfm.io/emcee/current',
#  '4.6',
#  '(0.007)',
#  '18.0',
#  '10.17909/t9-my41-h234',
#  '0.490,',
#  '6.5m',
#  '17.1',
#  '9.2',
#  '0.5–10',
#  'C.8',
#  'S.G.G.,',
#  '0.984483,',
#  '≈2.25',
#  'A.36',
#  '0.083,',
#  '±0.14',
#  '∼1.12',
#  '0.9(±0.05)',
#  '3.3/11.2',
#  'M.G.L.,',
#  '2.66',
#  'gauss-centre.eu',
#  'ADS/JAO.ALMA#2012.1.00712.S',
#  '39.6',
#  '97.2',
#  '30.7',
#  '0.44,',
#  '2.2255',
#  '>1.2',
#  '43.25)',
#  'M.N.,',
#  'C.A.W.H.,',
#  'https://jgagneastro.wordpress.com/the-montreal-spectral-library/',
#  '0.5–7',
#  '(3–3.5)',
#  '430.50',
#  'shocks.”',
#  '10.This',
#  '088.C-0666,',
#  '0.50,',
#  '8.03',
#  '8.6',
#  '(v14.0.0,',
#  '∼0.35',
#  '3.1.3',
#  '1.97',
#  '179.A-2005',
#  '∼656.00',
#  '68.C-0149(A),',
#  '∼0.5%',
#  'J.D.,',
#  '0.8;',
#  'M.M.,',
#  '0.75,',
#  '0.0031,',
#  '17−9.5',
#  '1113.1',
#  "'.mod'",
#  '(A.D.,',
#  '0.82',
#  '0.031',
#  '1.5–8.4',
#  '4C12.50',
#  '18.5arcsec',
#  '1.5–2,',
#  'A.16',
#  '0.3;',
#  '+0.2',
#  'M1.0AD0.3),',
#  '7.7',
#  'www.astro.yale.edu/smarts/glast/home.php',
#  'J0523.3−2527,',
#  '2.42',
#  '−2.8',
#  '16.8',
#  '0.692',
#  'A.E.,',
#  '(A.B.),',
#  '0.0025',
#  'M7.1',
#  '2.710',
#  '0.56',
#  '1.13',
#  '0.4;',
#  'A.13',
#  'P.G.,',
#  'C.J.,',
#  '0.001,',
#  '1354.09',
#  '0.5percent',
#  'A.S.M.,',
#  'UH:2.2',
#  '(0.05',
#  'CF0.1',
#  '2.7percent',
#  '8.3.2',
#  '5.7,',
#  'J.M.S,',
#  '2.3σ,',
#  '8.4',
#  '00:00:00.000',
#  '5.8,',
#  '1.)',
#  'Inc./National',
#  '>0.8',
#  '2.210',
#  '0.5),',
#  '(D.J.P.,',
#  '5301.97,',
#  'D.A.G.,',
#  '0.42,',
#  '(2.5–25',
#  '8.67,',
#  '99.99%',
#  '0.97',
#  '(e.g.Tucana,',
#  '0.258′′',
#  'B.9',
#  '∼0.8',
#  'http://irfu.cea.fr/xxl',
#  'http://leda.univ-lyon1.fr',
#  '(2015-03-23.778,',
#  ')=0.370',
#  '0.207',
#  '0.3)',
#  '(1.73),',
#  '99.7%',
#  '(10.3',
#  '5.9',
#  '#2015.1.00633.S',
#  'assumed.Two',
#  '−8.5',
#  '1/0.85',
#  '21.1',
#  '0.17)',
#  'HST-AR-14293.001-A',
#  '2.5–40',
#  '146/1001.46',
#  'W.N.)',
#  '≲0.07',
#  '1.1.4)',
#  'G.A.,',
#  '0.677',
#  '(0.23',
#  '−0.62',
#  'M6.5',
#  '(∼2.8',
#  '(3.6,',
#  '0.042',
#  'A.C.)',
#  '0.43',
#  'N11.7,',
#  '16.5',
#  '(3.3/11.2',
#  '6.2.3',
#  'panel).The',
#  'A.10',
#  '2.06',
#  'A.9',
#  '−0.34',
#  '0.7–0.9',
#  '0.23)',
#  'http://www.star.bristol.ac.uk/~mbt/topcat/',
#  'M1.0AD0.1',
#  'J025503.3−470049,',
#  '9.8',
#  '173.2',
#  '(0.79',
#  '3.6-m',
#  '1.4',
#  'approach—i.e.,',
#  '=1.331',
#  '266.4°',
#  '99.59',
#  'http://www.iiap.res.in/iao/hfosc.html',
#  'M.A.K.)',
#  'al.,',
#  'A.26',
#  '1.98,',
#  '4.2.3',
#  'http://www.2dfgrs.net/',
#  '0.2–0.3',
#  '2.35',
#  'i.e.,',
#  '−0.2,',
#  '2.2(±0.11)',
#  '0.057',
#  '4.0,',
#  'λλ7771.94,',
#  '60.00',
#  '0.04',
#  'A.34',
#  '(0.8',
#  'http://sngroup.oapd.inaf.it/foscgui.html',
#  '0.282,',
#  '(1.25),',
#  '0.051',
#  'http://enigma.physics.ucsb.edu/',
#  'B.2:',
#  'http://www.swift.ac.uk/analysis/xrt/#abs',
#  'V.S.T.,',
#  'l.o.s.)',
#  '7.24,',
#  'R.R.,',
#  '1.77',
#  'NSF.1713353',
#  '2.3.2-15-2016-00003',
#  '1.7',
#  '3.0',
#  '10.7',
#  '5.2.3',
#  '0.046',
#  '6.187',
#  '#2015.1.01259.S',
#  'O9.5',
#  '2.828,',
#  '13.79',
#  '14.064',
#  '7.3',
#  '63.7',
#  'https://skyserver.sdss.org/dr12/en/tools/chart/',
#  '−22.5),',
#  '7.52,',
#  '3.96',
#  'https://www.swpc.noaa.gov/products/goes-x-ray-flux',
#  '2.2),',
#  '28.67%',
#  '∼4.06',
#  'T.E.C.,',
#  '1.5%,',
#  '9.0',
#  '0.02,',
#  'J.C.M.,',
#  'https://archive.stsci.edu/prepds/vela',
#  '4.1',
#  'etc.,',
#  '4.2',
#  'J085910.0+294957)',
#  '−2.3,',
#  '618.6',
#  '15.0',
#  '12.6',
#  'M3.5',
#  'www.iphas.org',
#  '−0.80',
#  'xlink:href="apjaa566fieqn153.gif"></inline-graphic>',
#  '−1.15',
#  '4.3)',
#  '4.2;',
#  '±0.7',
#  'M.R.,',
#  '(0.104',
#  '3.5),',
#  '11.465',
#  'www.sdss.org',
#  '158.40',
#  '10.1',
#  'hmi.Ic',
#  '∼3.9',
#  '2.2.2',
#  '4.3.2',
#  '[0.5−2]',
#  '(23.9%)',
#  'L1/L0.5',
#  '0.6)',
#  '0.038,',
#  'exoplanets.org',
#  'http://www.swift.ac.uk/xrt_curves/cppdocs.php',
#  '0.4–3.0',
#  '0.045,',
#  '2.71',
#  'adi_Z=0.02_Lr=90au_taustop=0.1',
#  'T.K.G.,',
#  'http://www.chaos-project.fr',
#  'halo.This',
#  '0.50',
#  '1.5−2',
#  'etc.)',
#  'http://breakthroughprize.org',
#  '+2.9',
#  '6.28°)',
#  '6.08',
#  'B.3:',
#  'A.K.,',
#  'R.P.K.’s',
#  'HST-HF-51331.01',
#  '172.4',
#  '0.02d0',
#  '(4.2',
#  'M0.0AD1.0',
#  '0.7',
#  '9.3',
#  'T.d.J.,',
#  '(11.2',
#  '1.18',
#  '08.04.2015,',
#  '0.963',
#  '3.3',
#  '18.4%',
#  '0.0478',
#  '0.1–0.3',
#  '2.58',
#  'A.A.M.,',
#  '(0.2',
#  '(∼2.1',
#  '∼0.0066',
#  '−0.20,',
#  '−2.4',
#  '(A.M.,',
#  '156.4',
#  '17.9',
#  'http://gaia-kepler.fun',
#  '4.1.2',
#  '3.1.2',
#  '1.5;',
#  'A.C.,',
#  '0.33',
#  'available.)',
#  '10.301',
#  '2.7%',
#  '2.23',
#  '1.1,',
#  'http://gouldbelt-herschel.cea.fr',
#  '295.8',
#  '(~0.3−5',
#  '0.003,',
#  '0.881',
#  'J090113.23+465734.7',
#  '19.0',
#  '0.62',
#  'A.27',
#  '1.8,',
#  '0.025',
#  '3.5',
#  '−2.5,',
#  'https://www.cosmos.esa.int/web/xmmnewton/sas',
#  '≈0.01',
#  '0.0085',
#  '−8.2',
#  '∼0.6',
#  '22.10',
#  '1.35–1.75',
#  '1.42',
#  '5.0,',
#  '0.071,',
#  'ADS/JAO.ALMA#2013.1.00220.S,',
#  '0.46',
#  '37.7656,',
#  '2.0,',
#  '28.3',
#  'M.A.),',
#  '∼0.01',
#  '27.12',
#  'Heliosphere.”',
#  '1.4–1.5;',
#  '0.4–0.6',
#  '−0.3]',
#  '2.7',
#  "Y.L.W.'s",
#  '(5.25',
#  '16.18',
#  'http://www.stsci.edu/institute/software_hardware/pyraf',
#  'http://www.issibern.ch/teams/saturnastrometry/?page%20id=21',
#  'J151643.01+305344.4',
#  '1.15,',
#  '−0.2',
#  '1358/18.1',
#  'J1818.0–1607',
#  '733.295nm',
#  '16:20:03.8',
#  '0.05)',
#  '1997.2),',
#  'G342.0–01.7,',
#  'www.lrz.de',
#  '3.5.3',
#  '6141.7',
#  'H.K.,',
#  '1.30',
#  'http://cdsweb.u-strasbg.fr',
#  '0.475,',
#  '7.8',
#  '3.6.1',
#  '0.47,',
#  '0.5,',
#  '63,564.0',
#  '093.B-0693(A),',
#  '5.01',
#  '1.250',
#  '−2.3',
#  '0.18',
#  'http://adsabs.harvard.edu',
#  '1.39,',
#  '(1.7',
#  '1.2–3.2',
#  '6.1',
#  '1.2,',
#  'J.F.,',
#  '8.0',
#  '614.001.352',
#  '950.51,',
#  '0.2887,',
#  '4.0%',
#  '1.7,',
#  'D.G.,',
#  'www.aida-space.eu',
#  '90.50',
#  'S.C.,',
#  '4.5',
#  '2.99',
#  '0.3',
#  'A.25',
#  '1.23',
#  '6.19',
#  '0.95',
#  'E.J.A.,',
#  '1.288',
#  '1.36',
#  '(∼7.6',
#  '0.23',
#  '5183.6',
#  'http://hermes.sussex.ac.uk/',
#  'G015.684-0.29,',
#  '(0.99);',
#  '4.44',
#  '2.25',
#  'No.341157-COCO2CASA',
#  '0.97–1.66',
#  '0.25–4',
#  '(0.15)',
#  '6.2010',
#  '(−4.5',
#  '(−1.5,7.5,−0.05)',
#  'A.19',
#  '(99.983%',
#  'http://www.sternwarte.uni-erlangen.de/ISIS/',
#  'etc.),',
#  '(39.81',
#  '0.09,',
#  '4.4',
#  '63,564.5',
#  'www.syntheticuniverse.org',
#  '(∼0.66',
#  'SIDM0.1',
#  'HST-AR-13890.001,',
#  '67.9',
#  '10.6',
#  '783.25',
#  'Eqs.(',
#  '∼1.5',
#  '6.5au',
#  '±1.5',
#  '0.99',
#  'astropy.org',
#  '0.83,',
#  'http://www.it.umd.edu/hpcc',
#  '0.60,',
#  '0.7,',
#  '∼2.2',
#  '(8.7)',
#  '3.4.3',
#  'al.;',
#  '6.2,',
#  '0.08',
#  '≈4.5',
#  '19.27–35.97',
#  '0.3,',
#  '(4.4',
#  '2.54',
#  '(0.45',
#  '9.9',
#  '1.40',
#  '93.5',
#  '∼0.07',
#  '(S.S.T.,',
#  '1.296,',
#  '0.05',
#  '∼3.8',
#  'https://bitbucket.org/madamow/pymoogi.git',
#  '1.8)',
#  '0.274',
#  '2015.0',
#  '1.61',
#  '5.1',
#  '0.009]',
#  '2.2',
#  '9.0),',
#  '10.0–20.0',
#  'Z9.6',
#  '−0.91',
#  '3.5,',
#  '0.76',
#  '69.7',
#  '0.809,',
#  '−0.324',
#  '1.5s,',
#  'https://datatables.net/',
#  '0.021',
#  '3.4)',
#  '17.2',
#  'Y.S.L.,',
#  '0.2),',
#  'R.O.C.,',
#  '∼0.12',
#  '2.31M',
#  'S.V.,',
#  '(0.58)',
#  ...}

# %%
len(df)
# Out:
# 573132
